# %% [markdown]
# # First Layer

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import urllib.request
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains

import datetime
import time
import pandas as pd
import numpy as np
from datetime import date
date_today = date.today()

# %%
product_name = []
original_price = []
sale_price = []
product_url = []
picture_url = []
brand = []
product_type = []
timestamp = []

url_list = []
## Sale
sale = 'https://www.massimodutti.com/us/women/sale/our-selection-c1984536.html'
url_list.append(sale)
## Collection
col = 'https://www.massimodutti.com/us/women/collection/coats-%26-jackets-c1739517.html'
url_list.append(col)

for link in url_list:
    # open url in browser
    driver = webdriver.Chrome('/Users/fufufu/Documents/Python/Web Analytics/Selenium/chromedriver')
    driver.get(link)
    time.sleep(4) # cookie notification needs time to load
    driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/div/div/div/div[2]/button").click() # close coookie notification
    driver.find_element_by_xpath('/html/body/itx-catalog/section/div/category-page/section[1]/div[1]/category-toolbar/div/ul/li[2]/a[2]/i').click()
    # scroll page
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight") # Get scroll height
        while True:
            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            driver.execute_script("window.scrollTo(0, -1);") # need to scroll a bit up or the page wont load
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            # Wait to load page
            time.sleep(3)
            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                # till new_height = last_height, end loop, meaning cant scroll web page anymore, ie we are at end of this page
                break 
            last_height = new_height
        # at end of this page, get info from this page
        soup = BeautifulSoup(driver.page_source,'html.parser')
        for i in soup.find_all('itx-product-view', {'ng-if':'::(product.state.isProduct || product.state.isFakeBanner)'}):
            if i.find('a', {'ng-bind':'::$ctrl.product.name'}).text != '':
                brand.append('Massimo Dutti') # brand
                product_type.append("Women's Clothing") # product type
                timestamp.append(date_today) # time_stamp 
                product_name.append(i.find('a', {'ng-bind':'::$ctrl.product.name'}).text)  # product name
                if i.find('span', {'class':'old-price text-14-m ng-binding ng-scope'}) == None:
                    # if it == None, No sale price, 
                    # if it != None, sale price is sale price, original price is original price is original price
                    original_price.append(i.find('span', {'class':'price text-14-m ng-binding ng-scope'}).text) # original
                    sale_price.append(None)
                else:
                    original_price.append(i.find('span', {'class':'old-price text-14-m ng-binding ng-scope'}).text) # original
                    sale_price.append(i.find('span', {'class':'price text-14-m ng-binding ng-scope'}).text) # sale
                product_url.append(i.find('a', {'ng-click':'$ctrl.goToProductDetail($event)'}).get('ng-href')) # product url
                picture_url.append(i.find('img', {'class':'card9-image ng-scope'}).get('ng-src')) # pic url
            else:
                brand.append('Massimo Dutti') # brand
                product_type.append("Women's Clothing") # product type
                timestamp.append(date_today) # time_stamp 
                product_name.append(None) # product name
                original_price.append(None) # original price
                sale_price.append(None) # sale price
                product_url.append(None) # product url
                picture_url.append(None) # picture url
        try: # click the button to next page
            driver.find_element_by_xpath('/html/body/itx-catalog/section/div/category-page/section[1]/div[2]/category-nav/div/div[2]/a').click()
        except Exception as e:
            print(e)
            # if the button is not interactable, get the last page info
            soup = BeautifulSoup(driver.page_source,'html.parser')
            for i in soup.find_all('itx-product-view', {'ng-if':'::(product.state.isProduct || product.state.isFakeBanner)'}):
                if i.find('a', {'ng-bind':'::$ctrl.product.name'}).text != '':
                    brand.append('Massimo Dutti') # brand
                    product_type.append("Women's Clothing") # product type
                    timestamp.append(date_today) # time_stamp 
                    product_name.append(i.find('a', {'ng-bind':'::$ctrl.product.name'}).text)  # product name
                    if i.find('span', {'class':'old-price text-14-m ng-binding ng-scope'}) == None:
                        # if it == None, No sale price, 
                        # if it != None, sale price is sale price, original price is original price is original price
                        original_price.append(i.find('span', {'class':'price text-14-m ng-binding ng-scope'}).text) # original
                        sale_price.append(None)
                    else:
                        original_price.append(i.find('span', {'class':'old-price text-14-m ng-binding ng-scope'}).text) # original
                        sale_price.append(i.find('span', {'class':'price text-14-m ng-binding ng-scope'}).text) # sale
                    product_url.append(i.find('a', {'ng-click':'$ctrl.goToProductDetail($event)'}).get('ng-href')) # product url
                    picture_url.append(i.find('img', {'class':'card9-image ng-scope'}).get('ng-src')) # pic url
                else:
                    brand.append('Massimo Dutti') # brand
                    product_type.append("Women's Clothing") # product type
                    timestamp.append(date_today) # time_stamp 
                    product_name.append(None) # product name
                    original_price.append(None) # original price
                    sale_price.append(None) # sale price
                    product_url.append(None) # product url
                    picture_url.append(None) # picture url
            driver.close()
            break
# Out:
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/itx-catalog/section/div/category-page/section[1]/div[2]/category-nav/div/div[2]/a"}
#   (Session info: chrome=87.0.4280.88)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/itx-catalog/section/div/category-page/section[1]/div[2]/category-nav/div/div[2]/a"}
#   (Session info: chrome=87.0.4280.88)

# %%
column_names = ['product_name', 'original_price', 'sale_price', 'product_link', 'image_link']
df = pd.DataFrame(columns = column_names)

df['product_name'] = product_name
df['original_price'] = original_price
df['sale_price'] = sale_price
df['product_link'] = product_url
df['image_link'] = picture_url
df
# Out:
#                                           product_name original_price  \
# 0                                Black velvet jumpsuit        $249.00
# 1                                Black sequinned dress        $199.00
# 2                 Check wool blazer with velvet collar        $249.00
# 3                     Printed dress with shoulder pads        $179.00
# 4                 Short black dress with shoulder pads        $159.00
# ...                                                ...            ...
# 1616    Cream leather sock ankle boots with square toe        $199.00
# 1617                     Stretch high heel ankle boots        $199.00
# 1618                    White lace-up flat ankle boots        $199.00
# 1619                  Green loafers with buckle detail        $149.00
# 1620  White trainers with leather piece sole detailing        $149.00
#
#      sale_price                                       product_link  \
# 0       $179.00  https://www.massimodutti.com/us/women/sale/our...
# 1       $149.00  https://www.massimodutti.com/us/women/sale/our...
# 2       $179.00  https://www.massimodutti.com/us/women/sale/our...
# 3       $129.00  https://www.massimodutti.com/us/women/sale/our...
# 4       $119.00  https://www.massimodutti.com/us/women/sale/our...
# ...         ...                                                ...
# 1616    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1617    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1618    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1619    $110.00  https://www.massimodutti.com/us/women/join-lif...
# 1620    $110.00  https://www.massimodutti.com/us/women/join-lif...
#
#                                              image_link
# 0     https://static.massimodutti.net/3/photos/2021/...
# 1     https://static.massimodutti.net/3/photos/2021/...
# 2     https://static.massimodutti.net/3/photos/2021/...
# 3     https://static.massimodutti.net/3/photos/2021/...
# 4     https://static.massimodutti.net/3/photos/2021/...
# ...                                                 ...
# 1616  https://static.massimodutti.net/3/photos/2020/...
# 1617  https://static.massimodutti.net/3/photos/2020/...
# 1618  https://static.massimodutti.net/3/photos/2020/...
# 1619  https://static.massimodutti.net/3/photos/2020/...
# 1620  https://static.massimodutti.net/3/photos/2020/...
#
# [1621 rows x 5 columns]

# %%
df[(df['product_name']).apply(lambda x: str(x) == 'None')] # missing values
# Out:
#      product_name original_price sale_price product_link image_link
# 577          None           None       None         None       None
# 585          None           None       None         None       None
# 588          None           None       None         None       None
# 690          None           None       None         None       None
# 692          None           None       None         None       None
# 697          None           None       None         None       None
# 763          None           None       None         None       None
# 771          None           None       None         None       None
# 774          None           None       None         None       None
# 876          None           None       None         None       None
# 878          None           None       None         None       None
# 883          None           None       None         None       None
# 1396         None           None       None         None       None
# 1400         None           None       None         None       None
# 1407         None           None       None         None       None
# 1419         None           None       None         None       None
# 1423         None           None       None         None       None

# %%
# drop rows which have na
droplist = df[(df['product_name']).apply(lambda x: str(x) == 'None')].index.tolist()
df = df.drop(droplist)
df
# Out:
#                                           product_name original_price  \
# 0                                Black velvet jumpsuit        $249.00
# 1                                Black sequinned dress        $199.00
# 2                 Check wool blazer with velvet collar        $249.00
# 3                     Printed dress with shoulder pads        $179.00
# 4                 Short black dress with shoulder pads        $159.00
# ...                                                ...            ...
# 1616    Cream leather sock ankle boots with square toe        $199.00
# 1617                     Stretch high heel ankle boots        $199.00
# 1618                    White lace-up flat ankle boots        $199.00
# 1619                  Green loafers with buckle detail        $149.00
# 1620  White trainers with leather piece sole detailing        $149.00
#
#      sale_price                                       product_link  \
# 0       $179.00  https://www.massimodutti.com/us/women/sale/our...
# 1       $149.00  https://www.massimodutti.com/us/women/sale/our...
# 2       $179.00  https://www.massimodutti.com/us/women/sale/our...
# 3       $129.00  https://www.massimodutti.com/us/women/sale/our...
# 4       $119.00  https://www.massimodutti.com/us/women/sale/our...
# ...         ...                                                ...
# 1616    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1617    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1618    $150.00  https://www.massimodutti.com/us/women/join-lif...
# 1619    $110.00  https://www.massimodutti.com/us/women/join-lif...
# 1620    $110.00  https://www.massimodutti.com/us/women/join-lif...
#
#                                              image_link
# 0     https://static.massimodutti.net/3/photos/2021/...
# 1     https://static.massimodutti.net/3/photos/2021/...
# 2     https://static.massimodutti.net/3/photos/2021/...
# 3     https://static.massimodutti.net/3/photos/2021/...
# 4     https://static.massimodutti.net/3/photos/2021/...
# ...                                                 ...
# 1616  https://static.massimodutti.net/3/photos/2020/...
# 1617  https://static.massimodutti.net/3/photos/2020/...
# 1618  https://static.massimodutti.net/3/photos/2020/...
# 1619  https://static.massimodutti.net/3/photos/2020/...
# 1620  https://static.massimodutti.net/3/photos/2020/...
#
# [1604 rows x 5 columns]

# %% [markdown]
# # Second Layer

# %%
product_description = []
material = []
picture_name = []
color = []
counter = 0

driver = webdriver.Chrome(executable_path='/Users/fufufu/Documents/Python/Web Analytics/Selenium/chromedriver')
for link in df['product_link']:
    if(link) == product_url[0]: # only need to click for first url
        driver.get(link)
        time.sleep(4)
        driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/div/div/div/div[2]/button").click() # close coookie noti
        soup = BeautifulSoup(driver.page_source,'html.parser')
        # product_description
        if soup.find_all('li', {'class':'description ng-scope'}) != None:
            a = ''
            for des in soup.find_all('li', {'class':'description ng-scope'}):
                a += des.text + '; '
            product_description.append(a[:-2])
        else:
            product_description.append(None)
        # material 
        if soup.find_all('div', {'ng-repeat':"compositionPart in $ctrl.compositionParts | orderBy: 'part'"}) != None:
            res = ''
            for mat1 in soup.find_all('div', {'ng-repeat':"compositionPart in $ctrl.compositionParts | orderBy: 'part'"}):
                res += ('; ' + mat1.find('h4', {'class':'h5 ng-binding'}).text + ':')
                for mat2 in mat1.find_all('span', {'class':'p1 ng-binding ng-scope'}):
                    res += mat2.text
            material.append(res[2:])
        else:
            material.append(None)
        # picture name
        picture_name.append('Massimo_Dutti_Women_' + str(counter) + '.jpg') 
        # color
        if soup.find('span', {'class':'epsilon ng-binding'}) != None:
            color.append(soup.find('span', {'class':'epsilon ng-binding'}).text)
        else:
            color.append(None)
    else:
        driver.get(link)
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source,'html.parser')
        # product_description
        if soup.find_all('li', {'class':'description ng-scope'}) != None:
            a = ''
            for des in soup.find_all('li', {'class':'description ng-scope'}):
                a += des.text + '; '
            product_description.append(a[:-2])
        else:
            product_description.append(None)
        # material 
        if soup.find_all('div', {'ng-repeat':"compositionPart in $ctrl.compositionParts | orderBy: 'part'"}) != None:
            res = ''
            for mat1 in soup.find_all('div', {'ng-repeat':"compositionPart in $ctrl.compositionParts | orderBy: 'part'"}):
                res += ('; ' + mat1.find('h4', {'class':'h5 ng-binding'}).text + ':')
                for mat2 in mat1.find_all('span', {'class':'p1 ng-binding ng-scope'}):
                    res += mat2.text
            material.append(res[2:])
        else:
            material.append(None)
        # picture name
        picture_name.append('Massimo_Dutti_Women_' + str(counter) + '.jpg') 
        # color
        if soup.find('span', {'class':'epsilon ng-binding'}) != None:
            color.append(soup.find('span', {'class':'epsilon ng-binding'}).text)
        else:
            color.append(None)
    counter += 1 # update, for picture name
    brand.append('&Other Stories') # brand
    product_type.append("Women's Clothing") # product type
    timestamp.append(date_today) # time_stamp

# %%
column_names = ["brand", "product_type", "product_name", 'product_description', "price", 
                "sales_price", "color","material", "product_url", "picture_url", "timestamp", 'picture_name']
second_pass = pd.DataFrame(columns = column_names)
second_pass.brand = brand
second_pass.product_type = product_type
second_pass.product_name = df['product_name']
second_pass.product_description = product_description
second_pass.price = df['original_price']
second_pass.sales_price = df['sale_price']
second_pass.color = color
second_pass.material = material
second_pass.product_url = df['product_link']
second_pass.picture_url = df['image_link']
second_pass.timestamp = timestamp
second_pass.picture_name = picture_name
second_pass
# Out:
#               brand      product_type  \
# 0     Massimo Dutti  Women's Clothing
# 1     Massimo Dutti  Women's Clothing
# 2     Massimo Dutti  Women's Clothing
# 3     Massimo Dutti  Women's Clothing
# 4     Massimo Dutti  Women's Clothing
# ...             ...               ...
# 1599  Massimo Dutti  Women's Clothing
# 1600  Massimo Dutti  Women's Clothing
# 1601  Massimo Dutti  Women's Clothing
# 1602  Massimo Dutti  Women's Clothing
# 1603  Massimo Dutti  Women's Clothing
#
#                                           product_name  \
# 0                                Black velvet jumpsuit
# 1                                Black sequinned dress
# 2                 Check wool blazer with velvet collar
# 3                     Printed dress with shoulder pads
# 4                 Short black dress with shoulder pads
# ...                                                ...
# 1599    Cream leather sock ankle boots with square toe
# 1600                     Stretch high heel ankle boots
# 1601                    White lace-up flat ankle boots
# 1602                  Green loafers with buckle detail
# 1603  White trainers with leather piece sole detailing
#
#                                     product_description    price sales_price  \
# 0     Velvet fabric; Straight; Collar with multiway ...  $249.00     $179.00
# 1     Dress; Back vent; A button at the back of the ...  $199.00     $149.00
# 2     Blazer; Made of 100% wool; Peak lapel collar; ...  $249.00     $179.00
# 3     Flared; V-neck; Shoulder pads; Wrap fastening ...  $179.00     $129.00
# 4     Dress; V-neck; Shoulder pads; Side zip fasteni...  $159.00     $119.00
# ...                                                 ...      ...         ...
# 1599  Leather ankle boots; Inside zip for easy on/of...  $199.00     $150.00
# 1600  Leather; Logo on the insole; Stretch model wit...  $199.00     $150.00
# 1601  Leather ankle boots; Contrast laces; Inside zi...  $199.00     $150.00
# 1602  Leather shoes; Silver appliqués; Logo on the i...  $149.00     $110.00
# 1603  Leather trainers; Logo on the insole; Logo emb...  $149.00     $110.00
#
#       color                                           material  \
# 0     Black  Outer:viscose 80%, silk (mulberry) 20%; Lining...
# 1     Black  Outer:polyester 96%, elastane 4%; Lining:visco...
# 2      Grey               Outer:wool 100%; Lining:viscose 100%
# 3     Black  Outer:cupro 70%, viscose 30%; Lining:polyester...
# 4     Black   Outer:viscose 85%, wool 15%; Lining:viscose 100%
# ...     ...                                                ...
# 1599  Cream  Cut:goat leather 100%; Lining:sheep leather 50...
# 1600  Black  Cut:sheep leather 100%; Lining:sheep leather 6...
# 1601  Cream  Cut:cow leather 100%; Lining:sheep leather 70%...
# 1602  Green  Cut:goat leather 100%; Lining:sheep leather 80...
# 1603  Cream  Cut:cow leather 95%, polyurethane 5%; Lining:c...
#
#                                             product_url  \
# 0     https://www.massimodutti.com/us/women/sale/our...
# 1     https://www.massimodutti.com/us/women/sale/our...
# 2     https://www.massimodutti.com/us/women/sale/our...
# 3     https://www.massimodutti.com/us/women/sale/our...
# 4     https://www.massimodutti.com/us/women/sale/our...
# ...                                                 ...
# 1599  https://www.massimodutti.com/us/women/join-lif...
# 1600  https://www.massimodutti.com/us/women/join-lif...
# 1601  https://www.massimodutti.com/us/women/join-lif...
# 1602  https://www.massimodutti.com/us/women/join-lif...
# 1603  https://www.massimodutti.com/us/women/join-lif...
#
#                                             picture_url   timestamp  \
# 0     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 1     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 2     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 3     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 4     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# ...                                                 ...         ...
# 1599  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1600  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1601  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1602  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1603  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
#
#                       picture_name
# 0        Massimo_Dutti_Women_0.jpg
# 1        Massimo_Dutti_Women_1.jpg
# 2        Massimo_Dutti_Women_2.jpg
# 3        Massimo_Dutti_Women_3.jpg
# 4        Massimo_Dutti_Women_4.jpg
# ...                            ...
# 1599  Massimo_Dutti_Women_1599.jpg
# 1600  Massimo_Dutti_Women_1600.jpg
# 1601  Massimo_Dutti_Women_1601.jpg
# 1602  Massimo_Dutti_Women_1602.jpg
# 1603  Massimo_Dutti_Women_1603.jpg
#
# [1604 rows x 12 columns]

# %%
# drop rows which have nan, casue these rows are website promotions
droplist = second_pass[(second_pass['picture_url'].apply(lambda x: str(x) == 'nan'))].index.tolist()
second_pass = second_pass.drop(droplist)
second_pass
# Out:
#               brand      product_type  \
# 0     Massimo Dutti  Women's Clothing
# 1     Massimo Dutti  Women's Clothing
# 2     Massimo Dutti  Women's Clothing
# 3     Massimo Dutti  Women's Clothing
# 4     Massimo Dutti  Women's Clothing
# ...             ...               ...
# 1599  Massimo Dutti  Women's Clothing
# 1600  Massimo Dutti  Women's Clothing
# 1601  Massimo Dutti  Women's Clothing
# 1602  Massimo Dutti  Women's Clothing
# 1603  Massimo Dutti  Women's Clothing
#
#                                           product_name  \
# 0                                Black velvet jumpsuit
# 1                                Black sequinned dress
# 2                 Check wool blazer with velvet collar
# 3                     Printed dress with shoulder pads
# 4                 Short black dress with shoulder pads
# ...                                                ...
# 1599    Cream leather sock ankle boots with square toe
# 1600                     Stretch high heel ankle boots
# 1601                    White lace-up flat ankle boots
# 1602                  Green loafers with buckle detail
# 1603  White trainers with leather piece sole detailing
#
#                                     product_description    price sales_price  \
# 0     Velvet fabric; Straight; Collar with multiway ...  $249.00     $179.00
# 1     Dress; Back vent; A button at the back of the ...  $199.00     $149.00
# 2     Blazer; Made of 100% wool; Peak lapel collar; ...  $249.00     $179.00
# 3     Flared; V-neck; Shoulder pads; Wrap fastening ...  $179.00     $129.00
# 4     Dress; V-neck; Shoulder pads; Side zip fasteni...  $159.00     $119.00
# ...                                                 ...      ...         ...
# 1599  Leather ankle boots; Inside zip for easy on/of...  $199.00     $150.00
# 1600  Leather; Logo on the insole; Stretch model wit...  $199.00     $150.00
# 1601  Leather ankle boots; Contrast laces; Inside zi...  $199.00     $150.00
# 1602  Leather shoes; Silver appliqués; Logo on the i...  $149.00     $110.00
# 1603  Leather trainers; Logo on the insole; Logo emb...  $149.00     $110.00
#
#       color                                           material  \
# 0     Black  Outer:viscose 80%, silk (mulberry) 20%; Lining...
# 1     Black  Outer:polyester 96%, elastane 4%; Lining:visco...
# 2      Grey               Outer:wool 100%; Lining:viscose 100%
# 3     Black  Outer:cupro 70%, viscose 30%; Lining:polyester...
# 4     Black   Outer:viscose 85%, wool 15%; Lining:viscose 100%
# ...     ...                                                ...
# 1599  Cream  Cut:goat leather 100%; Lining:sheep leather 50...
# 1600  Black  Cut:sheep leather 100%; Lining:sheep leather 6...
# 1601  Cream  Cut:cow leather 100%; Lining:sheep leather 70%...
# 1602  Green  Cut:goat leather 100%; Lining:sheep leather 80...
# 1603  Cream  Cut:cow leather 95%, polyurethane 5%; Lining:c...
#
#                                             product_url  \
# 0     https://www.massimodutti.com/us/women/sale/our...
# 1     https://www.massimodutti.com/us/women/sale/our...
# 2     https://www.massimodutti.com/us/women/sale/our...
# 3     https://www.massimodutti.com/us/women/sale/our...
# 4     https://www.massimodutti.com/us/women/sale/our...
# ...                                                 ...
# 1599  https://www.massimodutti.com/us/women/join-lif...
# 1600  https://www.massimodutti.com/us/women/join-lif...
# 1601  https://www.massimodutti.com/us/women/join-lif...
# 1602  https://www.massimodutti.com/us/women/join-lif...
# 1603  https://www.massimodutti.com/us/women/join-lif...
#
#                                             picture_url   timestamp  \
# 0     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 1     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 2     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 3     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# 4     https://static.massimodutti.net/3/photos/2021/...  2020-12-29
# ...                                                 ...         ...
# 1599  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1600  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1601  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1602  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
# 1603  https://static.massimodutti.net/3/photos/2020/...  2020-12-29
#
#                       picture_name
# 0        Massimo_Dutti_Women_0.jpg
# 1        Massimo_Dutti_Women_1.jpg
# 2        Massimo_Dutti_Women_2.jpg
# 3        Massimo_Dutti_Women_3.jpg
# 4        Massimo_Dutti_Women_4.jpg
# ...                            ...
# 1599  Massimo_Dutti_Women_1599.jpg
# 1600  Massimo_Dutti_Women_1600.jpg
# 1601  Massimo_Dutti_Women_1601.jpg
# 1602  Massimo_Dutti_Women_1602.jpg
# 1603  Massimo_Dutti_Women_1603.jpg
#
# [1587 rows x 12 columns]

# %%
second_pass.to_csv("Massimo_Dutti_Women.csv", index=False, encoding = 'utf-8-sig')

# %%
import os
import requests as req

new_pd = pd.read_csv('Massimo_Dutti_Women.csv', encoding='utf-8-sig')
4523
os.mkdir('Massimo_Dutti_Women')
i = 1
for index, link in enumerate(new_pd['picture_url']):
    headers = {'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
    img_data = req.get(link, headers = headers).content
    with open('Massimo_Dutti_Women/'+ "Massimo_Dutti_Women_"+str(index+1)+'.jpg','wb+') as f:
        f.write(img_data)
    i+=1
