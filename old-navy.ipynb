# %% [markdown]
# ## First Layer

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

import datetime
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np
from datetime import date
date_today = date.today()

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("--disable-extensions")
driver = webdriver.Chrome(options=options, executable_path=r'/Users/ricardolu/Desktop/Design lab project/chromedriver')
driver.set_window_position(0, 0)
driver.set_window_size(1024, 768)

soups = []
driver.get("https://oldnavy.gap.com/browse/category.do?cid=10018&mlink=5151,1,HP_SC_b&clink=1")
time.sleep(1.5)

last_height = driver.execute_script("return document.body.scrollHeight")

counter = 1
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollBy(0, 768);")

    # Wait to load page
    time.sleep(.3)

    # Calculate new scroll height and compare with last scroll height
    new_height = 768 * counter
    if new_height >= last_height:
        break
    
    counter += 1

soup = BeautifulSoup(driver.page_source,'html.parser')
soups.append(soup)

#go to the second page
driver.get("https://oldnavy.gap.com/browse/category.do?cid=10018&mlink=5151,1,HP_SC_b&clink=1#pageId=1&department=136")
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1.5)
last_height = driver.execute_script("return document.body.scrollHeight")

counter = 1
while True:
    # Scroll down to bottom
    
    driver.execute_script("window.scrollBy(0, 768);")

    # Wait to load page
    time.sleep(.3)

    # Calculate new scroll height and compare with last scroll height
    new_height = 768 * counter
    if new_height >= last_height:
        break
    
    counter += 1
    
soup = BeautifulSoup(driver.page_source,'html.parser')
soups.append(soup)

#go to the third page
driver.get("hhttps://oldnavy.gap.com/browse/category.do?cid=10018&mlink=5151,1,HP_SC_b&clink=1#pageId=2&department=136")
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1.5)
last_height = driver.execute_script("return document.body.scrollHeight")

counter = 1
while True:
    # Scroll down to bottom
    
    driver.execute_script("window.scrollBy(0, 768);")

    # Wait to load page
    time.sleep(.3)

    # Calculate new scroll height and compare with last scroll height
    new_height = 768 * counter
    if new_height >= last_height:
        break
    
    counter += 1
soup = BeautifulSoup(driver.page_source,'html.parser')
soups.append(soup)

# %%
product_name = []
original_price = []
sale_price = []
product_url = []
image_url = []
brand = []
product_type = []
timestamp = []

for soup in soups:
    for i in soup.find_all('div',{'class':'product-card'}):
        if i.find('div',{'class':'product-card__name'}) != None:
            product_name.append((i.find('div',{'class':'product-card__name'})).text.strip())
        else:
            product_name.append(None)
        if i.find('span',{'class':'product-price__strike'}) != None:
            original_price.append((i.find('span',{'class':'product-price__strike'})).text.strip())
        else:
            original_price.append(None)
        if i.find('div',{'class':'product-price__highlight'}) != None:
            sale_price.append((i.find('div',{'class':'product-price__highlight'})).text.strip())
        elif i.find('div',{'class':'product-card-price'}) != None:
            sale_price.append((i.find('div',{'class':'product-card-price'})).text.strip())
        else:
            sale_price.append(None)
        if i.find('a',{'class':'css-0'}) != None:     
            product_url.append(i.find('a',{'class':'css-0'}).get('href'))
        if (i.find('div',{'class':'product-card__image-wrapper'}).find('img',{'class':'product-card__image'})) !=None:
            image_url.append((i.find('div',{'class':'product-card__image-wrapper'}).find('img',{'class':'product-card__image'})).get('src'))
        else:
            image_url.append(None)
        brand.append("old-navy")
        product_type.append("Women's Clothing")
        timestamp.append(date_today)

# %%
column_names = ["product_name", "original_price", "sale_price",'product_link', 'image_link']
df = pd.DataFrame(columns = column_names)

df['product_name'] = product_name
df['original_price'] = original_price
df['sale_price'] = sale_price
df['image_link'] = image_url
df['product_link'] = product_url

# %%
df
# Out:
#                                           product_name original_price  \
# 0          Soft-Brushed Utility Shirt Jacket for Women         $54.99
# 1    Oversized Plaid Flannel Boyfriend Tunic Shirt ...         $34.99
# 2    Extra High-Waisted Rockstar 360° Stretch Super...           None
# 3    Lightweight Diamond-Quilted Nylon Puffer Jacke...         $49.99
# 4    Mid-Rise Rockstar 360° Stretch Super Skinny Bl...           None
# ..                                                 ...            ...
# 895           Patterned Flannel Pajama Pants for Women         $19.99
# 896   Micro Performance Fleece Henley Hoodie for Women         $39.99
# 897    Patterned Flannel Jogger Pajama Pants for Women         $19.99
# 898             Thermal-Knit Pajama Leggings for Women         $24.99
# 899          Shirred Velvet Short-Sleeve Top for Women         $34.99
#
#     sale_price                                       product_link  \
# 0       $52.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 1       $30.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 2       $49.99  https://oldnavy.gap.com/browse/product.do?pid=...
# 3       $47.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 4       $44.99  https://oldnavy.gap.com/browse/product.do?pid=...
# ..         ...                                                ...
# 895     $18.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 896     $38.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 897     $18.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 898     $20.00  https://oldnavy.gap.com/browse/product.do?pid=...
# 899     $30.00  https://oldnavy.gap.com/browse/product.do?pid=...
#
#                                             image_link
# 0    https://www3.assets-gap.com/webcontent/0019/71...
# 1    https://www2.assets-gap.com/webcontent/0019/59...
# 2    https://www4.assets-gap.com/webcontent/0019/64...
# 3    https://www1.assets-gap.com/webcontent/0019/67...
# 4    https://www2.assets-gap.com/webcontent/0019/78...
# ..                                                 ...
# 895  https://www2.assets-gap.com/webcontent/0019/72...
# 896  https://www1.assets-gap.com/webcontent/0019/57...
# 897  https://www4.assets-gap.com/webcontent/0019/62...
# 898  https://www1.assets-gap.com/webcontent/0019/62...
# 899  https://www3.assets-gap.com/webcontent/0019/51...
#
# [900 rows x 5 columns]

# %% [markdown]
# ## Second Layer

# %%
product_description = []
material = []
picture_name = []
color = []
counter = 1

driver = webdriver.Chrome(options=options, executable_path=r'/Users/ricardolu/Desktop/Design lab project/chromedriver')
driver.set_window_size(1024, 888)
for link in product_url:
    driver.get(link)
    time.sleep(1)
    
    # in the case of not in stock
    soup = BeautifulSoup(driver.page_source,'html.parser')
    if soup.find('h1',{'class':'product-title__text'}) != None:
        driver.execute_script("window.scrollTo(0, 1000);")
        time.sleep(.3)
        detail_button = driver.find_element_by_css_selector('button[aria-label="Materials & Care - Opens Drawer"]')
        detail_button.click()
        time.sleep(.2)
        soup = BeautifulSoup(driver.page_source,'html.parser')

        item_color = []
        if soup.find('span',{'class':'swatch__image-wrapper invisible-border swatch--underlined'}).find('img') != None:
            for color_i in soup.find('span',{'class':'swatch__image-wrapper invisible-border swatch--underlined'}).find_all('img'):
                item_color.append(color_i.get("alt"))
            color.append(item_color)
        else:
            color.append(None)

        material.append(None)

        item_description = []
        if soup.find_all('li',{'class':'product-information-item__list-item'}) != None:
            for i in soup.find_all('li',{'class':'product-information-item__list-item'}):
                item_description.append(i.text.strip())
            product_description.append(item_description)
        else:
            product_description.append(None)
    else:
        color.append(None)
        material.append(None)
        product_description.append(None)
    

    picture_name.append('old-navy-women_' + str(counter) + '.jpg') # change variable
    counter += 1
driver.close()

# %%
for i,v in enumerate(product_description):
    if v != None:
        product_description[i] = v[0:3]
        item_material = []
        for j in v:
            if "%" in j:
                item_material.append(j)
        material[i] = item_material

# %%
column_names = ["brand", "product_type", "product_name", 'product_description', "price", 
                "sales_price", "color","material", "product_url", "picture_url", "timestamp", 'picture_name']
second_pass = pd.DataFrame(columns = column_names)
second_pass.brand = brand
second_pass.product_type = product_type
second_pass.product_name = product_name
second_pass.product_description = product_description
second_pass.price = original_price
second_pass.sales_price = sale_price
second_pass.color = color
second_pass.material = material
second_pass.product_url = product_url
second_pass.picture_url = image_url
second_pass.timestamp = timestamp
second_pass.picture_name = picture_name
second_pass
# Out:
#         brand      product_type  \
# 0    old-navy  Women's Clothing
# 1    old-navy  Women's Clothing
# 2    old-navy  Women's Clothing
# 3    old-navy  Women's Clothing
# 4    old-navy  Women's Clothing
# ..        ...               ...
# 895  old-navy  Women's Clothing
# 896  old-navy  Women's Clothing
# 897  old-navy  Women's Clothing
# 898  old-navy  Women's Clothing
# 899  old-navy  Women's Clothing
#
#                                           product_name  \
# 0          Soft-Brushed Utility Shirt Jacket for Women
# 1    Oversized Plaid Flannel Boyfriend Tunic Shirt ...
# 2    Extra High-Waisted Rockstar 360° Stretch Super...
# 3    Lightweight Diamond-Quilted Nylon Puffer Jacke...
# 4    Mid-Rise Rockstar 360° Stretch Super Skinny Bl...
# ..                                                 ...
# 895           Patterned Flannel Pajama Pants for Women
# 896   Micro Performance Fleece Henley Hoodie for Women
# 897    Patterned Flannel Jogger Pajama Pants for Women
# 898             Thermal-Knit Pajama Leggings for Women
# 899          Shirred Velvet Short-Sleeve Top for Women
#
#                                    product_description   price sales_price  \
# 0    [Spread collar., Seamed back yoke, with center...  $54.99      $52.00
# 1    [Spread collar., Seamed back yoke., Long drop-...  $34.99      $30.00
# 2    [Rockstar Super Skinny jeans have a legendary ...    None      $49.99
# 3    [Standing funnel-neck collar., Hidden five sna...  $49.99      $47.00
# 4    [Shimmy into Rockstar Super Skinny Jeggings, a...    None      $44.99
# ..                                                 ...     ...         ...
# 895  [Elasticized waistband, with adjustable twill-...  $19.99      $18.00
# 896  [Built-in hood, with standing collar., Long dr...  $39.99      $38.00
# 897  [Just in time for the holidays, get your whole...  $19.99      $18.00
# 898  [Elasticized rib-knit waistband., Faux fly, wi...  $24.99      $20.00
# 899  [Crew neck, with button-loop keyhole opening a...  $34.99      $30.00
#
#                    color                                           material  \
# 0      [Oatmeal Heather]              [63% polyester, 31% acrylic, 6% wool]
# 1     [Cocoa Pink Plaid]  [Cozy, soft-brushed 100% cotton flannel., 100%...
# 2        [Haley Destroy]  [75% cotton, 10% polyester, 8% elasterell, 5% ...
# 3          [Copper Moon]       [100% nylon, with polyester lining and fill]
# 4             [Ashleigh]  [75% cotton, 10% polyester, 8% elasterell, 5% ...
# ..                   ...                                                ...
# 895     [Pink Snowflake]  [Cozy, soft-brushed 100% cotton flannel, with ...
# 896         [Black Jack]                                   [100% polyester]
# 897      [Black Leopard]  [Cozy, soft-brushed 100% cotton flannel, with ...
# 898       [Snow Leopard]            [58% cotton, 37% polyester, 5% spandex]
# 899  [Icelandic Mineral]                                   [100% polyester]
#
#                                            product_url  \
# 0    https://oldnavy.gap.com/browse/product.do?pid=...
# 1    https://oldnavy.gap.com/browse/product.do?pid=...
# 2    https://oldnavy.gap.com/browse/product.do?pid=...
# 3    https://oldnavy.gap.com/browse/product.do?pid=...
# 4    https://oldnavy.gap.com/browse/product.do?pid=...
# ..                                                 ...
# 895  https://oldnavy.gap.com/browse/product.do?pid=...
# 896  https://oldnavy.gap.com/browse/product.do?pid=...
# 897  https://oldnavy.gap.com/browse/product.do?pid=...
# 898  https://oldnavy.gap.com/browse/product.do?pid=...
# 899  https://oldnavy.gap.com/browse/product.do?pid=...
#
#                                            picture_url   timestamp  \
# 0    https://www3.assets-gap.com/webcontent/0019/71...  2020-12-11
# 1    https://www2.assets-gap.com/webcontent/0019/59...  2020-12-11
# 2    https://www4.assets-gap.com/webcontent/0019/64...  2020-12-11
# 3    https://www1.assets-gap.com/webcontent/0019/67...  2020-12-11
# 4    https://www2.assets-gap.com/webcontent/0019/78...  2020-12-11
# ..                                                 ...         ...
# 895  https://www2.assets-gap.com/webcontent/0019/72...  2020-12-11
# 896  https://www1.assets-gap.com/webcontent/0019/57...  2020-12-11
# 897  https://www4.assets-gap.com/webcontent/0019/62...  2020-12-11
# 898  https://www1.assets-gap.com/webcontent/0019/62...  2020-12-11
# 899  https://www3.assets-gap.com/webcontent/0019/51...  2020-12-11
#
#                picture_name
# 0      old-navy-women_1.jpg
# 1      old-navy-women_2.jpg
# 2      old-navy-women_3.jpg
# 3      old-navy-women_4.jpg
# 4      old-navy-women_5.jpg
# ..                      ...
# 895  old-navy-women_896.jpg
# 896  old-navy-women_897.jpg
# 897  old-navy-women_898.jpg
# 898  old-navy-women_899.jpg
# 899  old-navy-women_900.jpg
#
# [900 rows x 12 columns]

# %%
second_pass.to_csv("old-navy-women.csv", index=False, encoding = 'utf-8-sig')

# %%
import os
import requests as req

new_pd = pd.read_csv('old-navy-women.csv', encoding='utf-8-sig')

os.mkdir('old-navy-women')
i = 1
for index, link in enumerate(new_pd['picture_url']):
    img_data = req.get(link).content
    with open('old-navy-women/'+ "old-navy-women_"+str(index+1)+'.jpg','wb+') as f:
        f.write(img_data)
    i+=1
