# %% [markdown]
# ## First Layer

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

import datetime
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np
from datetime import date
date_today = date.today()

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("--disable-extensions")
driver = webdriver.Chrome(options=options, executable_path=r'/Users/ricardolu/Desktop/Design lab project/chromedriver')
driver.set_window_position(0, 0)
driver.set_window_size(1024, 768)
soups = []

for i in range(1,11):
    driver.get("https://www.levi.com/US/en_US/clothing/men/c/levi_clothing_men?page="+str(i))
    # https://www.levi.com/US/en_US/clothing/women/c/levi_clothing_men?page=
    time.sleep(5)
    #X_button = driver.find_element_by_class_name('modal__close')
    #X_button.click()
    soup = BeautifulSoup(driver.page_source,'html.parser')
    soups.append(soup)
    

#print(soup.prettify())

# %%
product_name = []
sale_price = []
original_price = []
product_url = []
image_url = []
brand = []
product_type = []
timestamp = []

for soup in soups:
    for i in soup.find_all('div',{'class':'product-cell'}):
        product_name.append(i.find('div',{'class':'product-name'}).text)
        if i.find('div',{'class':'product-price'}) != 0:
            sale_price.append(i.find('div',{'class':'product-price'}).text.strip())
        product_url.append('https://www.levi.com'+str(i.find('a',{'class':'product-link lsco-col-xs-offset-1 lsco-col-lg-offset-0 lsco-col-xs-offset-right-1 lsco-col-lg-offset-right-0'}).get('href')))
        if (i.find('div',{'class':'image-container'}).find('img',{'class':'processed-image'})) !=None:
            image_url.append(i.find('div',{'class':'image-container'}).find('img',{'class':'processed-image'}).get('data-src'))
        else:
            image_url.append(None)
        brand.append("levis")
        product_type.append("Men's Clothing")
        timestamp.append(date_today)

# %%
for i, v in enumerate(sale_price):
    if "Sale Price" in v:
        sale_price[i] = v.replace("Sale Price", "").split("Original Price")[0]
        original_price.append(v.replace("Sale Price", "").split("Original Price")[1].replace("Temporary",""))
    else:
        original_price.append(None)

# %%
import pandas as pd

column_names = ["product_name", "original_price", "sale_price",'product_link', 'image_link']
df = pd.DataFrame(columns = column_names)


df['product_name'] = product_name
df['original_price'] = original_price
df['sale_price'] = sale_price
df['image_link'] = image_url
df['product_link'] = product_url

# %%
df
# Out:
#                                          product_name original_price  \
# 0                             Stay Loose Men's Jeans            None
# 1                    512™ Slim Taper Fit Men's Jeans            None
# 2                          511™ Slim Fit Men's Jeans            None
# 3             511™ Slim Fit Levi’s® Flex Men's Jeans            None
# 4     Reusable Reversible Printed Face Mask (3 Pack)            None
# ..                                                ...            ...
# 355                                     Cubano Shirt          $59.50
# 356                         Classic One Pocket Shirt         $128.00
# 357                                     Cubano Shirt          $59.50
# 358     Levi's® Classic XX Chino 9.5 in. Mens Shorts          $59.50
# 359                    Levi's® Logo Zip Hoodie (Big)          $69.50
#
#           sale_price                                       product_link  \
# 0             $98.00  https://www.levi.com/US/en_US/clothing/men/jea...
# 1    $69.50 - $79.50  https://www.levi.com/US/en_US/apparel/clothing...
# 2             $79.50  https://www.levi.com/US/en_US/clothing/men/jea...
# 3             $79.50  https://www.levi.com/US/en_US/clothing/men/jea...
# 4             $15.00  https://www.levi.com/US/en_US/accessories/band...
# ..               ...                                                ...
# 355           $31.98  https://www.levi.com/US/en_US/apparel/clothing...
# 356           $89.98  https://www.levi.com/US/en_US/apparel/clothing...
# 357           $40.98  https://www.levi.com/US/en_US/apparel/clothing...
# 358  $39.98 - $44.98  https://www.levi.com/US/en_US/apparel/clothing...
# 359           $49.98  https://www.levi.com/US/en_US/apparel/clothing...
#
#                                             image_link
# 0    https://lsco.scene7.com/is/image/lsco/29037000...
# 1    https://lsco.scene7.com/is/image/lsco/28833063...
# 2    https://lsco.scene7.com/is/image/lsco/04511150...
# 3    https://lsco.scene7.com/is/image/lsco/levis/cl...
# 4    https://lsco.scene7.com/is/image/lsco/levis/cl...
# ..                                                 ...
# 355  https://lsco.scene7.com/is/image/lsco/72625002...
# 356  https://lsco.scene7.com/is/image/lsco/levis/cl...
# 357  https://lsco.scene7.com/is/image/lsco/72625002...
# 358  https://lsco.scene7.com/is/image/lsco/levis/cl...
# 359  https://lsco.scene7.com/is/image/lsco/levis/cl...
#
# [360 rows x 5 columns]

# %% [markdown]
# ## Second Layer

# %%
product_description = []
material = []
picture_name = []
color = []
counter = 1


for link in product_url:
    driver.get(link)
    time.sleep(3)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    
    item_color = []
    if soup.find('div',{'class':'swatches'}) != None:
        for color_i in soup.find('div',{'class':'swatches'}).find_all('li'):
            item_color.append(color_i.get("aria-label"))
        color.append(item_color)
    else:
        color.append(None)
    
    item_material = []
    if len(soup.find_all('div',{'class':'contentContainer'})) >= 1:
        for i in soup.find_all('div',{'class':'contentContainer'}):
            for j in i.find_all("li"):
                item_material.append(j.text.strip())
        material.append(item_material)
    else:
        material.append(None)
    
    if len(soup.find_all('div',{'class':'contentContainer'})) >= 1:
        if (soup.find_all('div',{'class':'contentContainer'})[0].find("li")) != None:
            product_description.append(soup.find_all('div',{'class':'contentContainer'})[0].find("li").text.strip())
        else:
            product_description.append(None)
    else:
        product_description.append(None)

    picture_name.append('levis-men_' + str(counter) + '.jpg') # change variable
    counter += 1
driver.close()

# %%
for i,v in enumerate(color):
    if v != None:
        for u,j in enumerate(v):
            if j != None:
                color[i][u] = j.replace(" Medium Wash","").replace("- ","").replace(" Dark Wash","").replace(" Light Wash","").replace(" 3D Washed","")
        
for i,v in enumerate(sale_price):
    if v != None:
        sale_price[i] = v.replace("Temporary","")

# %%
material_a = []
for i,v in enumerate(material):
    if v != None:
        item_material = []
        for j in v:
            if "%" in j:
                item_material.append(j)
        if item_material == []:
            material_a.append(None)
        else:
            material_a.append(item_material)
    else:
        material_a.append(None)

# %%
column_names = ["brand", "product_type", "product_name", 'product_description', "price", 
                "sales_price", "color","material", "product_url", "picture_url", "timestamp", 'picture_name']
second_pass = pd.DataFrame(columns = column_names)
second_pass.brand = brand
second_pass.product_type = product_type
second_pass.product_name = product_name
second_pass.product_description = product_description
second_pass.price = original_price
second_pass.sales_price = sale_price
second_pass.color = color
second_pass.material = material_a
second_pass.product_url = product_url
second_pass.picture_url = image_url
second_pass.timestamp = timestamp
second_pass.picture_name = picture_name
second_pass.head()
# Out:
#    brand    product_type                                      product_name  \
# 0  levis  Men's Clothing                           Stay Loose Men's Jeans
# 1  levis  Men's Clothing                  512™ Slim Taper Fit Men's Jeans
# 2  levis  Men's Clothing                        511™ Slim Fit Men's Jeans
# 3  levis  Men's Clothing           511™ Slim Fit Levi’s® Flex Men's Jeans
# 4  levis  Men's Clothing   Reusable Reversible Printed Face Mask (3 Pack)
#
#                                  product_description price      sales_price  \
# 0  A baggy silhouette that draws inspiration from...  None           $98.00
# 1                      Slimmer leg than Levi's® 511™  None  $69.50 - $79.50
# 2                    A modern slim with room to move  None           $79.50
# 3                    A modern slim with room to move  None           $79.50
# 4            Essential 3-pack of reusable face masks  None           $15.00
#
#                                                color  \
# 0                                     [Tannin Brown]
# 1  [Goldenrod -, Dark Hollow, Shooting Star, Nati...
# 2  [Nightshine Black, Chain Rinse, Baltic Navy Su...
# 3  [Orinda -, Headed East Grey, Headed South, Sun...
# 4                      [Multi-Color Printed Paisley]
#
#                                   material  \
# 0                   [77% Cotton, 23% hemp]
# 1                [99% Cotton, 1% Elastane]
# 2                [99% Cotton, 1% Elastane]
# 3  [94% Cotton, 4% Polyester, 2% Elastane]
# 4                            [100% Cotton]
#
#                                          product_url  \
# 0  https://www.levi.com/US/en_US/clothing/men/jea...
# 1  https://www.levi.com/US/en_US/apparel/clothing...
# 2  https://www.levi.com/US/en_US/clothing/men/jea...
# 3  https://www.levi.com/US/en_US/clothing/men/jea...
# 4  https://www.levi.com/US/en_US/accessories/band...
#
#                                          picture_url   timestamp  \
# 0  https://lsco.scene7.com/is/image/lsco/29037000...  2020-12-12
# 1  https://lsco.scene7.com/is/image/lsco/28833063...  2020-12-12
# 2  https://lsco.scene7.com/is/image/lsco/04511150...  2020-12-12
# 3  https://lsco.scene7.com/is/image/lsco/levis/cl...  2020-12-12
# 4  https://lsco.scene7.com/is/image/lsco/levis/cl...  2020-12-12
#
#       picture_name
# 0  levis-men_1.jpg
# 1  levis-men_2.jpg
# 2  levis-men_3.jpg
# 3  levis-men_4.jpg
# 4  levis-men_5.jpg

# %%
second_pass.to_csv("levis-men.csv", index=False, encoding = 'utf-8-sig')

# %%
import os
import requests as req

new_pd = pd.read_csv('levis-men.csv', encoding='utf-8-sig')

os.mkdir('levis-men')
i = 1
for index, link in enumerate(new_pd['picture_url']):
    img_data = req.get(link).content
    with open('levis-men/'+ "levis-men_"+str(index+1)+'.jpg','wb+') as f:
        f.write(img_data)
    i+=1

# %%
len(material_a)
# Out:
# 360
